# %% [markdown]
# **This notebook is an exercise in the [Computer Vision](https://www.kaggle.com/learn/computer-vision) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/custom-convnets).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In these exercises, you'll build a custom convnet with performance competitive to the VGG16 model from Lesson 1.
#
# Get started by running the code cell below.

# %%
# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.computer_vision.ex5 import *

# Imports
import os, warnings
import matplotlib.pyplot as plt
from matplotlib import gridspec

import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image_dataset_from_directory

# Reproducability
def set_seed(seed=31415):
    np.random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    os.environ['TF_DETERMINISTIC_OPS'] = '1'
set_seed()

# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('image', cmap='magma')
warnings.filterwarnings("ignore") # to clean up output cells


# Load training and validation sets
ds_train_ = image_dataset_from_directory(
    '../input/car-or-truck/train',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=True,
)
ds_valid_ = image_dataset_from_directory(
    '../input/car-or-truck/valid',
    labels='inferred',
    label_mode='binary',
    image_size=[128, 128],
    interpolation='nearest',
    batch_size=64,
    shuffle=False,
)

# Data Pipeline
def convert_to_float(image, label):
    image = tf.image.convert_image_dtype(image, dtype=tf.float32)
    return image, label

AUTOTUNE = tf.data.experimental.AUTOTUNE
ds_train = (
    ds_train_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
ds_valid = (
    ds_valid_
    .map(convert_to_float)
    .cache()
    .prefetch(buffer_size=AUTOTUNE)
)
# Out:
# Found 5117 files belonging to 2 classes.
# Found 5051 files belonging to 2 classes.

# %% [markdown]
# # Design a Convnet #
#
# Let's design a convolutional network with a block architecture like we saw in the tutorial. The model from the example had three blocks, each with a single convolutional layer. Its performance on the "Car or Truck" problem was okay, but far from what the pretrained VGG16 could achieve. It might be that our simple network lacks the ability to extract sufficiently complex features. We could try improving the model either by adding more blocks or by adding convolutions to the blocks we have.
#
# Let's go with the second approach. We'll keep the three block structure, but increase the number of `Conv2D` layer in the second block to two, and in the third block to three.
#
# <figure>
# <!-- <img src="./images/2-convmodel-2.png" width="250" alt="Diagram of a convolutional model."> -->
# <img src="https://i.imgur.com/Vko6nCK.png" width="250" alt="Diagram of a convolutional model.">
# </figure>
#
# # 1) Define Model #
#
# Given the diagram above, complete the model by defining the layers of the third block.

# %%
from tensorflow import keras
from tensorflow.keras import layers

model = keras.Sequential([
    # Block One
    layers.Conv2D(filters=32, kernel_size=3, activation='relu', padding='same',
                  input_shape=[128, 128, 3]),
    layers.MaxPool2D(),

    # Block Two
    layers.Conv2D(filters=64, kernel_size=3, activation='relu', padding='same'),
    layers.MaxPool2D(),

    # Block Three
    layers.Conv2D(filters=128,kernel_size=3,activation="relu",padding="same"),
    layers.Conv2D(filters=128,kernel_size=3,activation="relu",padding="same"),
    layers.MaxPool2D(),

    # Head
    layers.Flatten(),
    layers.Dense(6, activation='relu'),
    layers.Dropout(0.2),
    layers.Dense(1, activation='sigmoid'),
])

# Check your answer
q_1.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_1.hint()
#q_1.solution()

# %% [markdown]
# # 2) Compile #
#
# To prepare for training, compile the model with an appropriate loss and accuracy metric for the "Car or Truck" dataset.

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss = "binary_crossentropy",
    metrics=["binary_accuracy"]
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(epsilon=0.01),
    loss='binary_crossentropy',
    metrics=['binary_accuracy'],
)
q_2.assert_check_passed()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, let's test the performance of this new model. First run this cell to fit the model to the training set.

# %%
history = model.fit(
    ds_train,
    validation_data=ds_valid,
    epochs=50,
)
# Out:
# Epoch 1/50
# 80/80 [==============================] - 36s 365ms/step - loss: 0.6816 - binary_accuracy: 0.5744 - val_loss: 0.6691 - val_binary_accuracy: 0.5785
# Epoch 2/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6669 - binary_accuracy: 0.5787 - val_loss: 0.6612 - val_binary_accuracy: 0.5785
# Epoch 3/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6618 - binary_accuracy: 0.5787 - val_loss: 0.6506 - val_binary_accuracy: 0.5785
# Epoch 4/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6527 - binary_accuracy: 0.5787 - val_loss: 0.6456 - val_binary_accuracy: 0.5785
# Epoch 5/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6474 - binary_accuracy: 0.6033 - val_loss: 0.6368 - val_binary_accuracy: 0.6177
# Epoch 6/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6380 - binary_accuracy: 0.6340 - val_loss: 0.6327 - val_binary_accuracy: 0.5977
# Epoch 7/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6350 - binary_accuracy: 0.6373 - val_loss: 0.6364 - val_binary_accuracy: 0.6141
# Epoch 8/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6260 - binary_accuracy: 0.6553 - val_loss: 0.6207 - val_binary_accuracy: 0.6424
# Epoch 9/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.6206 - binary_accuracy: 0.6639 - val_loss: 0.6139 - val_binary_accuracy: 0.6494
# Epoch 10/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.6137 - binary_accuracy: 0.6678 - val_loss: 0.6028 - val_binary_accuracy: 0.6684
# Epoch 11/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.5954 - binary_accuracy: 0.6844 - val_loss: 0.5884 - val_binary_accuracy: 0.6854
# Epoch 12/50
# 80/80 [==============================] - 5s 60ms/step - loss: 0.5822 - binary_accuracy: 0.6955 - val_loss: 0.5745 - val_binary_accuracy: 0.7022
# Epoch 13/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.5621 - binary_accuracy: 0.7086 - val_loss: 0.5608 - val_binary_accuracy: 0.7163
# Epoch 14/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.5489 - binary_accuracy: 0.7295 - val_loss: 0.5664 - val_binary_accuracy: 0.7018
# Epoch 15/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.5252 - binary_accuracy: 0.7508 - val_loss: 0.5395 - val_binary_accuracy: 0.7278
# Epoch 16/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.5080 - binary_accuracy: 0.7573 - val_loss: 0.5432 - val_binary_accuracy: 0.7127
# Epoch 17/50
# 80/80 [==============================] - 5s 60ms/step - loss: 0.4862 - binary_accuracy: 0.7727 - val_loss: 0.4983 - val_binary_accuracy: 0.7589
# Epoch 18/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.4453 - binary_accuracy: 0.8011 - val_loss: 0.4711 - val_binary_accuracy: 0.7751
# Epoch 19/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.4229 - binary_accuracy: 0.8140 - val_loss: 0.4583 - val_binary_accuracy: 0.7840
# Epoch 20/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.3892 - binary_accuracy: 0.8321 - val_loss: 0.4558 - val_binary_accuracy: 0.7951
# Epoch 21/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.3734 - binary_accuracy: 0.8405 - val_loss: 0.4943 - val_binary_accuracy: 0.7480
# Epoch 22/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.3533 - binary_accuracy: 0.8476 - val_loss: 0.4457 - val_binary_accuracy: 0.7975
# Epoch 23/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.3098 - binary_accuracy: 0.8732 - val_loss: 0.4569 - val_binary_accuracy: 0.8048
# Epoch 24/50
# 80/80 [==============================] - 5s 61ms/step - loss: 0.2861 - binary_accuracy: 0.8835 - val_loss: 0.4322 - val_binary_accuracy: 0.8113
# Epoch 25/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2799 - binary_accuracy: 0.8853 - val_loss: 0.4282 - val_binary_accuracy: 0.8234
# Epoch 26/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2479 - binary_accuracy: 0.9040 - val_loss: 0.4400 - val_binary_accuracy: 0.8194
# Epoch 27/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2370 - binary_accuracy: 0.9085 - val_loss: 0.5022 - val_binary_accuracy: 0.7925
# Epoch 28/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2384 - binary_accuracy: 0.8997 - val_loss: 0.4741 - val_binary_accuracy: 0.8121
# Epoch 29/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2226 - binary_accuracy: 0.9076 - val_loss: 0.4434 - val_binary_accuracy: 0.8278
# Epoch 30/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.2120 - binary_accuracy: 0.9156 - val_loss: 0.4085 - val_binary_accuracy: 0.8325
# Epoch 31/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.2031 - binary_accuracy: 0.9191 - val_loss: 0.4449 - val_binary_accuracy: 0.8347
# Epoch 32/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1871 - binary_accuracy: 0.9310 - val_loss: 0.4908 - val_binary_accuracy: 0.8331
# Epoch 33/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.1652 - binary_accuracy: 0.9396 - val_loss: 0.5933 - val_binary_accuracy: 0.8171
# Epoch 34/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1505 - binary_accuracy: 0.9496 - val_loss: 0.6088 - val_binary_accuracy: 0.8123
# Epoch 35/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1485 - binary_accuracy: 0.9455 - val_loss: 0.6579 - val_binary_accuracy: 0.8133
# Epoch 36/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1322 - binary_accuracy: 0.9535 - val_loss: 0.6552 - val_binary_accuracy: 0.8111
# Epoch 37/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.1179 - binary_accuracy: 0.9625 - val_loss: 0.6647 - val_binary_accuracy: 0.8131
# Epoch 38/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.1251 - binary_accuracy: 0.9594 - val_loss: 0.5701 - val_binary_accuracy: 0.8268
# Epoch 39/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.1352 - binary_accuracy: 0.9552 - val_loss: 0.5619 - val_binary_accuracy: 0.8379
# Epoch 40/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.1062 - binary_accuracy: 0.9646 - val_loss: 0.5526 - val_binary_accuracy: 0.8351
# Epoch 41/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.1078 - binary_accuracy: 0.9668 - val_loss: 0.5933 - val_binary_accuracy: 0.8416
# Epoch 42/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0965 - binary_accuracy: 0.9701 - val_loss: 0.6236 - val_binary_accuracy: 0.8272
# Epoch 43/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0961 - binary_accuracy: 0.9707 - val_loss: 0.6052 - val_binary_accuracy: 0.8289
# Epoch 44/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0882 - binary_accuracy: 0.9767 - val_loss: 0.5622 - val_binary_accuracy: 0.8153
# Epoch 45/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0875 - binary_accuracy: 0.9758 - val_loss: 0.6057 - val_binary_accuracy: 0.8153
# Epoch 46/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0841 - binary_accuracy: 0.9758 - val_loss: 0.5966 - val_binary_accuracy: 0.8238
# Epoch 47/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0866 - binary_accuracy: 0.9750 - val_loss: 0.6022 - val_binary_accuracy: 0.8333
# Epoch 48/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0881 - binary_accuracy: 0.9748 - val_loss: 0.6627 - val_binary_accuracy: 0.8470
# Epoch 49/50
# 80/80 [==============================] - 5s 59ms/step - loss: 0.0720 - binary_accuracy: 0.9799 - val_loss: 0.6278 - val_binary_accuracy: 0.8450
# Epoch 50/50
# 80/80 [==============================] - 5s 58ms/step - loss: 0.0695 - binary_accuracy: 0.9808 - val_loss: 0.8564 - val_binary_accuracy: 0.8285

# %% [markdown]
# And now run the cell below to plot the loss and metric curves for this training run.

# %%
import pandas as pd
history_frame = pd.DataFrame(history.history)
history_frame.loc[:, ['loss', 'val_loss']].plot()
history_frame.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot();

# %% [markdown]
# # 3) Train the Model #
#
# How would you interpret these training curves? Did this model improve upon the model from the tutorial?

# %%
# View the solution (Run this code cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
#
# The learning curves for the model from the tutorial diverged fairly rapidly. This would indicate that it was prone to overfitting and in need of some regularization. The additional layer in our new model would make it even more prone to overfitting. However, adding some regularization with the `Dropout` layer helped prevent this. These changes improved the validation accuracy of the model by several points.

# %% [markdown]
# # Conclusion #
#
# These exercises showed you how to design a custom convolutional network to solve a specific classification problem. Though most models these days will be built on top of a pretrained base, it certain circumstances a smaller custom convnet might still be preferable -- such as with a smaller or unusual dataset or when computing resources are very limited. As you saw here, for certain problems they can perform just as well as a pretrained model.
#
# # Keep Going #
#
# Continue on to [**Lesson 6**](https://www.kaggle.com/ryanholbrook/data-augmentation), where you'll learn a widely-used technique that can give a boost to your training data: **data augmentation**.

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/computer-vision/discussion) to chat with other learners.*
