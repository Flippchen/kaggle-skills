# %% [markdown]
# **This notebook is an exercise in the [Intro to Deep Learning](https://www.kaggle.com/learn/intro-to-deep-learning) course.  You can reference the tutorial at [this link](https://www.kaggle.com/ryanholbrook/binary-classification).**
#
# ---

# %% [markdown]
# # Introduction #
#
# In this exercise, you'll build a model to predict hotel cancellations with a binary classifier.

# %%
# Setup plotting
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
# Set Matplotlib defaults
plt.rc('figure', autolayout=True)
plt.rc('axes', labelweight='bold', labelsize='large',
       titleweight='bold', titlesize=18, titlepad=10)
plt.rc('animation', html='html5')

# Setup feedback system
from learntools.core import binder
binder.bind(globals())
from learntools.deep_learning_intro.ex6 import *

# %% [markdown]
# First, load the *Hotel Cancellations* dataset.

# %%
import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer

hotel = pd.read_csv('../input/dl-course-data/hotel.csv')

X = hotel.copy()
y = X.pop('is_canceled')

X['arrival_date_month'] = \
    X['arrival_date_month'].map(
        {'January':1, 'February': 2, 'March':3,
         'April':4, 'May':5, 'June':6, 'July':7,
         'August':8, 'September':9, 'October':10,
         'November':11, 'December':12}
    )

features_num = [
    "lead_time", "arrival_date_week_number",
    "arrival_date_day_of_month", "stays_in_weekend_nights",
    "stays_in_week_nights", "adults", "children", "babies",
    "is_repeated_guest", "previous_cancellations",
    "previous_bookings_not_canceled", "required_car_parking_spaces",
    "total_of_special_requests", "adr",
]
features_cat = [
    "hotel", "arrival_date_month", "meal",
    "market_segment", "distribution_channel",
    "reserved_room_type", "deposit_type", "customer_type",
]

transformer_num = make_pipeline(
    SimpleImputer(strategy="constant"), # there are a few missing values
    StandardScaler(),
)
transformer_cat = make_pipeline(
    SimpleImputer(strategy="constant", fill_value="NA"),
    OneHotEncoder(handle_unknown='ignore'),
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat, features_cat),
)

# stratify - make sure classes are evenlly represented across splits
X_train, X_valid, y_train, y_valid = \
    train_test_split(X, y, stratify=y, train_size=0.75)

X_train = preprocessor.fit_transform(X_train)
X_valid = preprocessor.transform(X_valid)

input_shape = [X_train.shape[1]]

# %% [markdown]
# # 1) Define Model #
#
# The model we'll use this time will have both batch normalization and dropout layers. To ease reading we've broken the diagram into blocks, but you can define it layer by layer as usual.
#
# Define a model with an architecture given by this diagram:
#
# <figure style="padding: 1em;">
# <img src="https://i.imgur.com/V04o59Z.png" width="400" alt="Diagram of network architecture: BatchNorm, Dense, BatchNorm, Dropout, Dense, BatchNorm, Dropout, Dense.">
# <figcaption style="textalign: center; font-style: italic"><center>Diagram of a binary classifier.</center></figcaption>
# </figure>

# %%
from tensorflow import keras
from tensorflow.keras import layers

# YOUR CODE HERE: define the model given in the diagram
model = keras.Sequential([
    layers.BatchNormalization(input_shape=input_shape),
    layers.Dense(units=256,activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(units=256,activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(rate=0.3),
    layers.Dense(units=1, activation="sigmoid")
])

# Check your answer
q_1.check()
# Out:
# Correct

# %% [markdown]
# # 2) Add Optimizer, Loss, and Metric #
#
# Now compile the model with the Adam optimizer and binary versions of the cross-entropy loss and accuracy metric.

# %%
# YOUR CODE HERE
model.compile(
    optimizer="adam",
    loss='binary_crossentropy',
    metrics=["binary_accuracy"]
)

# Check your answer
q_2.check()
# Out:
# Correct

# %%
# Lines below will give you a hint or solution code
#q_2.hint()
#q_2.solution()

# %% [markdown]
# Finally, run this cell to train the model and view the learning curves. It may run for around 60 to 70 epochs, which could take a minute or two.

# %%
early_stopping = keras.callbacks.EarlyStopping(
    patience=5,
    min_delta=0.001,
    restore_best_weights=True,
)
history = model.fit(
    X_train, y_train,
    validation_data=(X_valid, y_valid),
    batch_size=512,
    epochs=200,
    callbacks=[early_stopping],
)

history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot(title="Cross-entropy")
history_df.loc[:, ['binary_accuracy', 'val_binary_accuracy']].plot(title="Accuracy")
# Out:
# Epoch 1/200
# 175/175 [==============================] - 4s 6ms/step - loss: 0.4843 - binary_accuracy: 0.7703 - val_loss: 0.4349 - val_binary_accuracy: 0.7985
# Epoch 2/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4215 - binary_accuracy: 0.8016 - val_loss: 0.4020 - val_binary_accuracy: 0.8108
# Epoch 3/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4105 - binary_accuracy: 0.8077 - val_loss: 0.3944 - val_binary_accuracy: 0.8173
# Epoch 4/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.4019 - binary_accuracy: 0.8122 - val_loss: 0.3902 - val_binary_accuracy: 0.8179
# Epoch 5/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3968 - binary_accuracy: 0.8149 - val_loss: 0.3875 - val_binary_accuracy: 0.8192
# Epoch 6/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3915 - binary_accuracy: 0.8172 - val_loss: 0.3836 - val_binary_accuracy: 0.8216
# Epoch 7/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3884 - binary_accuracy: 0.8189 - val_loss: 0.3839 - val_binary_accuracy: 0.8263
# Epoch 8/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3847 - binary_accuracy: 0.8223 - val_loss: 0.3796 - val_binary_accuracy: 0.8273
# Epoch 9/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3815 - binary_accuracy: 0.8234 - val_loss: 0.3769 - val_binary_accuracy: 0.8275
# Epoch 10/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3789 - binary_accuracy: 0.8247 - val_loss: 0.3749 - val_binary_accuracy: 0.8293
# Epoch 11/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3765 - binary_accuracy: 0.8254 - val_loss: 0.3717 - val_binary_accuracy: 0.8294
# Epoch 12/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3742 - binary_accuracy: 0.8266 - val_loss: 0.3700 - val_binary_accuracy: 0.8306
# Epoch 13/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3711 - binary_accuracy: 0.8283 - val_loss: 0.3691 - val_binary_accuracy: 0.8294
# Epoch 14/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3699 - binary_accuracy: 0.8292 - val_loss: 0.3664 - val_binary_accuracy: 0.8310
# Epoch 15/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3680 - binary_accuracy: 0.8304 - val_loss: 0.3652 - val_binary_accuracy: 0.8308
# Epoch 16/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3668 - binary_accuracy: 0.8307 - val_loss: 0.3651 - val_binary_accuracy: 0.8312
# Epoch 17/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3655 - binary_accuracy: 0.8303 - val_loss: 0.3655 - val_binary_accuracy: 0.8311
# Epoch 18/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3618 - binary_accuracy: 0.8328 - val_loss: 0.3627 - val_binary_accuracy: 0.8331
# Epoch 19/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3616 - binary_accuracy: 0.8334 - val_loss: 0.3611 - val_binary_accuracy: 0.8339
# Epoch 20/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3589 - binary_accuracy: 0.8347 - val_loss: 0.3629 - val_binary_accuracy: 0.8330
# Epoch 21/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3589 - binary_accuracy: 0.8341 - val_loss: 0.3615 - val_binary_accuracy: 0.8330
# Epoch 22/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3575 - binary_accuracy: 0.8348 - val_loss: 0.3598 - val_binary_accuracy: 0.8338
# Epoch 23/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3552 - binary_accuracy: 0.8366 - val_loss: 0.3596 - val_binary_accuracy: 0.8351
# Epoch 24/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3540 - binary_accuracy: 0.8368 - val_loss: 0.3613 - val_binary_accuracy: 0.8327
# Epoch 25/200
# 175/175 [==============================] - 1s 7ms/step - loss: 0.3518 - binary_accuracy: 0.8386 - val_loss: 0.3568 - val_binary_accuracy: 0.8350
# Epoch 26/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3535 - binary_accuracy: 0.8367 - val_loss: 0.3580 - val_binary_accuracy: 0.8361
# Epoch 27/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3519 - binary_accuracy: 0.8374 - val_loss: 0.3612 - val_binary_accuracy: 0.8343
# Epoch 28/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3502 - binary_accuracy: 0.8383 - val_loss: 0.3556 - val_binary_accuracy: 0.8380
# Epoch 29/200
# 175/175 [==============================] - 1s 6ms/step - loss: 0.3488 - binary_accuracy: 0.8392 - val_loss: 0.3534 - val_binary_accuracy: 0.8367
# Epoch 30/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3477 - binary_accuracy: 0.8384 - val_loss: 0.3530 - val_binary_accuracy: 0.8378
# Epoch 31/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3469 - binary_accuracy: 0.8405 - val_loss: 0.3531 - val_binary_accuracy: 0.8379
# Epoch 32/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3458 - binary_accuracy: 0.8398 - val_loss: 0.3532 - val_binary_accuracy: 0.8383
# Epoch 33/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3459 - binary_accuracy: 0.8399 - val_loss: 0.3516 - val_binary_accuracy: 0.8386
# Epoch 34/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3434 - binary_accuracy: 0.8414 - val_loss: 0.3517 - val_binary_accuracy: 0.8381
# Epoch 35/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3432 - binary_accuracy: 0.8426 - val_loss: 0.3513 - val_binary_accuracy: 0.8391
# Epoch 36/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3422 - binary_accuracy: 0.8426 - val_loss: 0.3518 - val_binary_accuracy: 0.8370
# Epoch 37/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3405 - binary_accuracy: 0.8433 - val_loss: 0.3543 - val_binary_accuracy: 0.8378
# Epoch 38/200
# 175/175 [==============================] - 1s 5ms/step - loss: 0.3390 - binary_accuracy: 0.8437 - val_loss: 0.3522 - val_binary_accuracy: 0.8399
# <AxesSubplot:title={'center':'Accuracy'}>

# %% [markdown]
# # 3) Train and Evaluate #
#
#
# What do you think about the learning curves? Does it look like the model underfit or overfit? Was the cross-entropy loss a good stand-in for accuracy?

# %%
# View the solution (Run this cell to receive credit!)
q_3.check()
# Out:
# Correct:
#
# Though we can see the training loss continuing to fall, the early stopping callback prevented any overfitting. Moreover, the accuracy rose at the same rate as the cross-entropy fell, so it appears that minimizing cross-entropy was a good stand-in. All in all, it looks like this training was a success!

# %% [markdown]
# # Conclusion #
#
# Congratulations! You've completed Kaggle's *Introduction to Deep Learning* course!
#
# With your new skills you're ready to take on more advanced applications like computer vision and sentiment classification. What would you like to do next?
#
# Why not try one of our *Getting Started* competitions?
#
# - Classify images with TPUs in [**Petals to the Metal**](https://www.kaggle.com/c/tpu-getting-started)
# - Create art with GANs in [**I'm Something of a Painter Myself**](https://www.kaggle.com/c/gan-getting-started)
# - Classify Tweets in [**Real or Not? NLP with Disaster Tweets**](https://www.kaggle.com/c/nlp-getting-started)
# - Detect contradiction and entailment in [**Contradictory, My Dear Watson**](https://www.kaggle.com/c/contradictory-my-dear-watson)
#
# Until next time, Kagglers!

# %% [markdown]
# ---
#
#
#
#
# *Have questions or comments? Visit the [course discussion forum](https://www.kaggle.com/learn/intro-to-deep-learning/discussion) to chat with other learners.*
